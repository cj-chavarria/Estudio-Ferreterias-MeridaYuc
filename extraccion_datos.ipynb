# %% [markdown]
# # Extracción de Datos: Ferreterías en Mérida, Yucatán
#
# ## Metodología de Recolección de Datos
#
# Este notebook documenta el proceso de extracción de datos de ferreterías utilizando la API de Google Places. La estrategia empleada consiste en:
#
# 1. **Segmentación geográfica**: División del área de estudio en múltiples viewports rectangulares
# 2. **Búsqueda sistemática**: Consulta de cada viewport para obtener datos completos
#
# **Área de estudio**: Zona Norte-Poniente de Mérida, Yucatán
#
# **Fuente de datos**: Google Places API (New)

# %%
import folium
import time
import requests
from dotenv import load_dotenv
import os
import pandas as pd

# %% [markdown]
# ---
#
# ### Función de Creación de Viewports
#
# Esta función genera los viewports en el mapa para dividir el área de estudio en secciones manejables.
#
# **Parámetros:**
# - `start_lat, start_lng`: Coordenadas de inicio
# - `rows, cols`: Número de filas y columnas de rectángulos
# - `delta`: Tamaño de cada viewport
# - `start_k`: Identificador inicial
# - `color`: Color de visualización
#
# **Propósito**: La API de Google Places tiene limitaciones de área por consulta. Esta segmentación permite una cobertura completa sin perder resultados.

# %%
def create_viewports(map, start_lat, start_lng, rows, cols, delta, start_k, color):
    viewports = []
    k = start_k
    
    for i in range(rows):
        for j in range(cols):
            low = [start_lat + i * delta, start_lng + j * delta]
            high = [start_lat + (i + 1) * delta, start_lng + (j + 1) * delta]
            
            folium.Rectangle(
                color = 'black',
                weight = 0.6,
                bounds = [low, high],
                tooltip = k,
                fill = True,
                fill_color = color
            ).add_to(map)
            
            k += 1
            
            if delta < 0:
                viewports.append((tuple(high), tuple(low)))
            else:
                viewports.append((tuple(low), tuple(high)))
    
    return viewports, k

# %% [markdown]
# ---
#
# ### Configuración del Mapa de Búsqueda
#
# Creación de la cuadrícula de viewports que cubre toda el área de estudio. Se definen 7 grupos de viewports para abarcar las zonas deseadas sin hacer busquedas de mas:
#
# - **Azul**: Área principal (70 viewports)
# - **Verde**: Extensión este (36 viewports)
# - **Rojo**: Extensión noreste (30 viewports)
# - **Naranja**: Extensión noroeste (10 viewports)
# - **Amarillo**: Extensión sureste (12 viewports)
# - **Cyan**: Extensión central-oeste (18 viewports)
# - **Negro**: Extensión este adicional (30 viewports)

# %%
m = folium.Map(location=[20.9939879883004, -89.62853393602846], min_zoom=12)

rectangles_viewports = []
delta = 0.0092
k = 0

first_lat, first_lng = 20.947641060948502, -89.70360532775601
viewports_1, k = create_viewports(m, first_lat, first_lng, 10, 7, delta, k, 'blue')
rectangles_viewports.extend(viewports_1)

sec_lat, sec_lng = rectangles_viewports[63][1]
viewports_2, k = create_viewports(m, sec_lat, sec_lng, 6, 6, delta, k, 'green')
rectangles_viewports.extend(viewports_2)

third_lat, third_lng = rectangles_viewports[27][1]
viewports_3, k = create_viewports(m, third_lat, third_lng, 6, 5, delta, k, 'red')
rectangles_viewports.extend(viewports_3)

fourth_lat, fourth_lng = rectangles_viewports[5][0]
viewports_4, k = create_viewports(m, fourth_lat, fourth_lng, 2, 5, -delta, k,'orange')
rectangles_viewports.extend(viewports_4)

fifth_lat, fifth_lng = rectangles_viewports[115][1]
viewports_5, k = create_viewports(m, fifth_lat, fifth_lng, 4,3, delta, k, 'yellow')
rectangles_viewports.extend(viewports_5)

sixth_lat, sixth_lng = rectangles_viewports[63][0]
viewports_6, k = create_viewports(m, sixth_lat, sixth_lng, 6, 3, -delta, k, 'cyan')
rectangles_viewports.extend(viewports_6)

seventh_lat, seventh_lng = rectangles_viewports[69][1]
viewports_7, k = create_viewports(m, seventh_lat, seventh_lng,5,6, delta, k, 'black')
rectangles_viewports.extend(viewports_7)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_317d43fde15c526c77fefff866e9e068 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_317d43fde15c526c77fefff866e9e068&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_317d43fde15c526c77fefff866e9e068 = L.map(
#                 &quot;map_317d43fde15c526c77fefff866e9e068&quot;,
#                 {
#                     center: [20.9939879883004, -89.62853393602846],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a2cd8aa0d65b1ae076798b30c4b6e41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 12,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a2cd8aa0d65b1ae076798b30c4b6e41.addTo(map_317d43fde15c526c77fefff866e9e068);
#
#
#             var rectangle_77c5c8ccae9f085f9667dbc9e7d66044 = L.rectangle(
#                 [[20.947641060948502, -89.70360532775601], [20.956841060948502, -89.694405327756]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_317d43fde15c526c77fefff866e9e068);
#
#
#             rectangle_77c5c8ccae9f085f9667dbc9e7d66044.bindTooltip(
#                 `&lt;div&gt;
#                      0
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var rectangle_66530b06cb65d4bffe616e802740f10a = L.rectangle(
#                 [[20.947641060948502, -89.694405327756], [20.956841060948502, -89.68520532775601]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_317d43fde15c526c77fefff866e9e068);
#
#
#             rectangle_66530b06cb65d4bffe616e802740f10a.bindTooltip(
#                 `&lt;div&gt;
#                      1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var rectangle_1bc1c4dee09e72d6bfdfc0498af61294 = L.rectangle(
#                 [[20.947641060948502, -89.68520532775601], [20.956841060948502, -89.676005327756]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_317d43fde15c526c77fefff866e9e068);
#
#
#             rectangle_1bc1c4dee09e72d6bfdfc0498af61294.bindTooltip(
#                 `&lt;div&gt;
#                      2
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var rectangle_490ae8c1910cda72d29556a56ad986f2 = L.rectangle(
#                 [[20.947641060948502, -89.676005327756], [20.956841060948502, -89.66680532775601]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.6}
#             ).addTo(map_317d43fde15c526c77fefff866e9e068);
#
#
#             rectangle_490ae8c1910cda72d29556a56ad986f2.bindTooltip(
#                 `&lt;div&gt;
#                      3
#                  &lt;/div&gt;`,

# %% [markdown]
# #### Verificación de Viewports Totales

# %%
len(rectangles_viewports)
# Out:
# 206

# %% [markdown]
# ---
#
# ### Cargar API key

# %%
load_dotenv()
API_KEY = os.getenv('API_KEY')

# %% [markdown]
# ---
#
# ### Configuración de la API
#
# Preparación de los parámetros para las consultas a Google Places API:
#
# **Endpoint**: `places:searchText` (New Places API)
#
# **Campos solicitados**:
# - `id`: Identificador único
# - `displayName`: Nombre del negocio
# - `formattedAddress`: Dirección completa
# - `location`: Coordenadas geográficas (lat/lng)
# - `rating`: Calificación promedio
# - `userRatingCount`: Número total de reseñas
# - `websiteUri`: Sitio web o red social
# - `primaryType`: Tipo de negocio

# %%
search_url = "https://places.googleapis.com/v1/places:searchText"

search_headers = {
    'Content-Type' : 'application/json',
    'X-Goog-Api-Key': API_KEY,
    'X-Goog-FieldMask': 'places.id,places.displayName,places.formattedAddress,places.location,places.rating,places.userRatingCount,places.websiteUri,places.primaryType'
}

# %% [markdown]
# ---
#
# ### Proceso de Extracción de Datos
#
# Búsqueda sistemática de ferreterías en todos los viewports definidos.
#
# **Proceso:**
# 1. Iteración sobre cada viewport (206 áreas)
# 2. Consulta a la API con filtros:
#    - Término de búsqueda: "ferreteria"
#    - Tipo incluido: "hardware_store"
#    - Restricción geográfica: rectángulo del viewport
# 3. Agregación de resultados
# 4. Guardar en .csv

# %%
raw_data = []

for low, high in rectangles_viewports:
    try: 
        search_json = {
            'textQuery' : 'ferreteria',
            'includedType': 'hardware_store',
            'locationRestriction' : {
                'rectangle':{
                    'low':{
                        'latitude' : low[0],
                        'longitude' : low[1]
                    },
                    'high':{
                        'latitude': high[0],
                        'longitude': high[1]
                        
                    }
                }
            }
        }
        
        response = requests.post(url = search_url, json=search_json, headers = search_headers)
        response.raise_for_status()
        
        data = response.json()
        raw_data.extend(data.get('places', []))
        
        time.sleep(0.5)
        
    except requests.exceptions.RequestException as e:
        print(f'ERROR!!! --> {e}')
        time.sleep(1)

pd.DataFrame(raw_data).to_csv('datos_raw.csv', index=False)

# %% [markdown]
# **Resultado**: Dataset completo exportado a `datos_raw.csv`
#
# ---
#
# ### Visualizacion del dataset

# %%
pd.read_csv('datos_raw.csv', index_col=0)
# Out:
#                                                               formattedAddress  \
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw  Perif. de Mérida Lic. Manuel Berzunza S/N, 972...
# ChIJych2UCtzVo8RrIjQgPltzjk  Perif. de Mérida Lic. Manuel Berzunza, 97312 M...
# ChIJiVWqvydzVo8RwNMdR4Mi72E  x75C, C. 34 675, Tixcacal Opichen, Sin Nombre ...
# ChIJX_mhVdhyVo8RBfz5X7rnOpk  C. 81 511, Ampliación Tixcacal Opichen, 97249 ...
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc  C. 77ᶜ 598, Ampliación Tixcacal Opichen, 97000...
# ...                                                                        ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M  Calle 79 732D X 92 y 94, Almendros, Cd Caucel,...
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI  C. 38 243, Hacienda Sodzil Nte., 97115 Mérida,...
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg  Perif. de Mérida Lic. Manuel Berzunza 27, Sin ...
# ChIJKc63ZBN3Vo8R0lEG-qsvigk  Calle 40 Diagonal, Temozon Norte, 97302 Mérida...
# ChIJ982KWAB1Vo8Rr10KSh24Y-E  Calle 20 & Calle 15, 97302 Xcanatún, Yuc., Mexico
#
#                                                                       location  \
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw  {'latitude': 20.955513, 'longitude': -89.6999282}
# ChIJych2UCtzVo8RrIjQgPltzjk  {'latitude': 20.9555047, 'longitude': -89.699936}
# ChIJiVWqvydzVo8RwNMdR4Mi72E  {'latitude': 20.9520469, 'longitude': -89.6897...
# ChIJX_mhVdhyVo8RBfz5X7rnOpk  {'latitude': 20.947645899999998, 'longitude': ...
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc  {'latitude': 20.9491932, 'longitude': -89.6925...
# ...                                                                        ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M  {'latitude': 20.9922643, 'longitude': -89.7090...
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI  {'latitude': 21.045245299999998, 'longitude': ...
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg  {'latitude': 21.0494014, 'longitude': -89.6329...
# ChIJKc63ZBN3Vo8R0lEG-qsvigk  {'latitude': 21.0551119, 'longitude': -89.6156...
# ChIJ982KWAB1Vo8Rr10KSh24Y-E  {'latitude': 21.0791922, 'longitude': -89.6279...
#
#                              rating  \
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw     4.2
# ChIJych2UCtzVo8RrIjQgPltzjk     NaN
# ChIJiVWqvydzVo8RwNMdR4Mi72E     4.4
# ChIJX_mhVdhyVo8RBfz5X7rnOpk     4.6
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc     4.9
# ...                             ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M     5.0
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI     4.9
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg     NaN
# ChIJKc63ZBN3Vo8R0lEG-qsvigk     4.2
# ChIJ982KWAB1Vo8Rr10KSh24Y-E     NaN
#
#                                                             websiteUri  \
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw                 http://www.surpesa.com.mx/
# ChIJych2UCtzVo8RrIjQgPltzjk                                        NaN
# ChIJiVWqvydzVo8RwNMdR4Mi72E                                        NaN
# ChIJX_mhVdhyVo8RBfz5X7rnOpk                                        NaN
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc                                        NaN
# ...                                                                ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M                                        NaN
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI                                        NaN
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg  https://www.facebook.com/RefacasaManrique
# ChIJKc63ZBN3Vo8R0lEG-qsvigk     https://fabs.mx/ferreteria-en-temozon/
# ChIJ982KWAB1Vo8Rr10KSh24Y-E                                        NaN
#
#                              userRatingCount  \
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw             40.0
# ChIJych2UCtzVo8RrIjQgPltzjk              NaN
# ChIJiVWqvydzVo8RwNMdR4Mi72E            160.0
# ChIJX_mhVdhyVo8RBfz5X7rnOpk            253.0
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc             12.0
# ...                                      ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M              4.0
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI             23.0
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg              NaN
# ChIJKc63ZBN3Vo8R0lEG-qsvigk             15.0
# ChIJ982KWAB1Vo8Rr10KSh24Y-E              NaN
#
#                                                                    displayName  \
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw    {'text': 'SURPESA Cedis', 'languageCode': 'en'}
# ChIJych2UCtzVo8RrIjQgPltzjk  {'text': 'La Tienda del Plomero y el Electrici...
# ChIJiVWqvydzVo8RwNMdR4Mi72E  {'text': 'Ferrotlapalería El Farahon Dorado', ...
# ChIJX_mhVdhyVo8RBfz5X7rnOpk  {'text': 'Tlapalería Vizcarra', 'languageCode'...
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc  {'text': 'Ferrotlapalería El Foquito', 'langua...
# ...                                                                        ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M  {'text': 'Ferrotlapaleria "La Marmota" Suc Alm...
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI  {'text': 'Ferrotlapalería Angie y Cristhian', ...
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg   {'text': 'Manrique CEDIS', 'languageCode': 'es'}
# ChIJKc63ZBN3Vo8R0lEG-qsvigk  {'text': 'Fabs Ferretería - Temozón', 'languag...
# ChIJ982KWAB1Vo8Rr10KSh24Y-E  {'text': 'Ferrotlapaleria la 20', 'languageCod...
#
#                                 primaryType
# id
# ChIJoS84RStzVo8RMZAc0ytcFmw  hardware_store
# ChIJych2UCtzVo8RrIjQgPltzjk  hardware_store
# ChIJiVWqvydzVo8RwNMdR4Mi72E  hardware_store
# ChIJX_mhVdhyVo8RBfz5X7rnOpk  hardware_store
# ChIJ4dRnBDFzVo8RZ9I0-bg8Dpc  hardware_store
# ...                                     ...
# ChIJAQ4vPSMNVo8RT5yOxe-nN3M  hardware_store
# ChIJGwMKhIB2Vo8RSFFFgFZgbsI  hardware_store
# ChIJEfy_U1Z1Vo8RzLXG9-q-_Kg  hardware_store
# ChIJKc63ZBN3Vo8R0lEG-qsvigk  hardware_store
# ChIJ982KWAB1Vo8Rr10KSh24Y-E  hardware_store
#
# [260 rows x 7 columns]
